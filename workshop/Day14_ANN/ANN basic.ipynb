# %%
from scipy.special import expit

# %%
import numpy as np

# %%
x = list(np.arange(-20,20,0.1))

# %%
x
# Out:
# [-20.0,
#  -19.899999999999999,
#  -19.799999999999997,
#  -19.699999999999996,
#  -19.599999999999994,
#  -19.499999999999993,
#  -19.399999999999991,
#  -19.29999999999999,
#  -19.199999999999989,
#  -19.099999999999987,
#  -18.999999999999986,
#  -18.899999999999984,
#  -18.799999999999983,
#  -18.699999999999982,
#  -18.59999999999998,
#  -18.499999999999979,
#  -18.399999999999977,
#  -18.299999999999976,
#  -18.199999999999974,
#  -18.099999999999973,
#  -17.999999999999972,
#  -17.89999999999997,
#  -17.799999999999969,
#  -17.699999999999967,
#  -17.599999999999966,
#  -17.499999999999964,
#  -17.399999999999963,
#  -17.299999999999962,
#  -17.19999999999996,
#  -17.099999999999959,
#  -16.999999999999957,
#  -16.899999999999956,
#  -16.799999999999955,
#  -16.699999999999953,
#  -16.599999999999952,
#  -16.49999999999995,
#  -16.399999999999949,
#  -16.299999999999947,
#  -16.199999999999946,
#  -16.099999999999945,
#  -15.999999999999943,
#  -15.899999999999942,
# ...

# %%
y = map(lambda a:expit(a), x)

# %%
from pylab import *

# %%
plt.plot(y)

# %%
plt.show()

# %%
plt.plot(x)
plt.show()

# %%
z = x*np.array(y)
plt.plot(z)
plt.show()

# %%
X = np.matrix(((0,0,1,1),(0,1,0,1)))
W1 = np.matrix(((-4.8,5.1),(4.6,-5.2)))
W2 = np.matrix(((5.9),(5.2))).T
B1 = np.matrix((-2.6))
B2 = np.matrix((-2.7))

# %%
X
# Out:
# matrix([[0, 0, 1, 1],
#         [0, 1, 0, 1]])

# %%
W1
# Out:
# matrix([[-4.8,  5.1],
#         [ 4.6, -5.2]])

# %%
W2
# Out:
# matrix([[ 5.9],
#         [ 5.2]])

# %%
A1 = expit(np.matmul(W1.T,X) + B1)
A1
# Out:
# matrix([[  6.91384203e-02,   8.80797078e-01,   6.10879359e-04,
#            5.73241759e-02],
#         [  6.91384203e-02,   4.09567165e-04,   9.24141820e-01,
#            6.29733561e-02]])

# %%
A2 = expit(np.matmul(W2.T,A1) + B2)
A2
# Out:
# matrix([[ 0.12646711,  0.92405993,  0.89178853,  0.11564577]])

# %%
X
# Out:
# matrix([[0, 0, 1, 1],
#         [0, 1, 0, 1]])
