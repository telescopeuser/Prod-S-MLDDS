# %% [markdown]
# # Naive Bayes classifiers: Spam Filter

# %% [markdown]
# Naive Bayes classifiers work by correlating the use of tokens (typically words, or sometimes other things), with spam and non-spam e-mails and then using Bayes' theorem to calculate a probability that an email is or is not spam.
#
# Naive Bayes spam filtering is a baseline technique for dealing with spam that can tailor itself to the email needs of individual users and give low false positive spam detection rates that are generally acceptable to users. It is one of the oldest ways of doing spam filtering, with roots in the 1990s.

# %% [markdown]
# Bag of words representation:
#     - The order of words in the message is not important.
#     - Each word is conditionally independent of the others given message class (spam / non spam)

# %% [markdown]
# The Bayesian Rule is:

# %% [markdown]
# <img class="irc_mi" src="http://www.saedsayad.com/images/Bayes_rule.png" onload="google.aft&amp;&amp;google.aft(this)" width="385" height="220" style="margin-top: 0px;" alt="Image result for naive bayes">

# %% [markdown]
# Where we could say..
# <img style="display:block;float:none;margin-left:auto;margin-right:auto;border:0;" title="naivebayeseq2" src="https://computersciencesource.files.wordpress.com/2010/01/naivebayeseq2_thumb.png?w=360&amp;h=83" alt="naivebayeseq2" width="240" height="55" border="0" originalw="240" originalh="55" src-orig="https://computersciencesource.files.wordpress.com/2010/01/naivebayeseq2_thumb.png?w=240&amp;h=55" scale="1.5">

# %% [markdown]
# <img class="irc_mi" src="https://i.stack.imgur.com/0QOII.png" onload="google.aft&amp;&amp;google.aft(this)" width="685" height="355" style="margin-top: 1px;" alt="Image result for naive bayes spam filter">

# %%
import os
import io
import numpy
from pandas import DataFrame
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

def readFiles(path):
    for root, dirnames, filenames in os.walk(path):
        for filename in filenames:
            path = os.path.join(root, filename)

            inBody = False
            lines = []
            f = io.open(path, 'r', encoding='latin1')
            for line in f:
                if inBody:
                    lines.append(line)
                elif line == '\n':
                    inBody = True
            f.close()
            message = '\n'.join(lines)
            yield path, message

def dataFrameFromDirectory(path, classification):
    rows = []
    index = []
    for filename, message in readFiles(path):
        rows.append({'message': message, 'class': classification})
        index.append(filename)

    return DataFrame(rows, index=index)

data = DataFrame({'message': [], 'class': []})

data = data.append(dataFrameFromDirectory('spam', 'spam'))
data = data.append(dataFrameFromDirectory('ham', 'ham'))

# %% [markdown]
# Let's take a look at the data.

# %%
data
# Out:
#                                             class  \
# spam\00001.7848dde101aa985090474a91ec93fcf0  spam
# spam\00002.d94f1b97e48ed3b553b3508d116e6a09  spam
# spam\00003.2ee33bc6eacdb11f38d052c44819ba6c  spam
# spam\00004.eac8de8d759b7e74154f142194282724  spam
# spam\00005.57696a39d7d84318ce497886896bf90d  spam
# spam\00006.5ab5620d3d7c6c0db76234556a16f6c1  spam
# spam\00007.d8521faf753ff9ee989122f6816f87d7  spam
# spam\00008.dfd941deb10f5eed78b1594b131c9266  spam
# spam\00009.027bf6e0b0c4ab34db3ce0ea4bf2edab  spam
# spam\00010.445affef4c70feec58f9198cfbc22997  spam
# spam\00011.61816b9ad167657773a427d890d0468e  spam
# spam\00012.381e4f512915109ba1e0853a7a8407b2  spam
# spam\00013.d3f0b591a65f116ea5d9d4ad919f83aa  spam
# spam\00014.7d38c46424f24fc8012ac15a95a2ac14  spam
# spam\00015.048434ab64c86cf890eda1326a5643f5  spam
# spam\00016.67fb281761ca1051a22ec3f21917e7c0  spam
# spam\00017.1a938ecddd047b93cbd7ed92c241e6d1  spam
# spam\00007.d8521faf753ff9ee989122f6816f87d7  Help wanted.  We are a 14 year old fortune 500...
# spam\00008.dfd941deb10f5eed78b1594b131c9266  <html>\n\n<head>\n\n<title>ReliaQuote - Save U...
# spam\00009.027bf6e0b0c4ab34db3ce0ea4bf2edab  TIRED OF THE BULL OUT THERE?\n\nWant To Stop L...
# spam\00010.445affef4c70feec58f9198cfbc22997  Dear ricardo1 ,\n\n\n\n<html>\n\n<body>\n\n<ce...
# spam\00011.61816b9ad167657773a427d890d0468e  Cellular Phone Accessories All At Below Wholes...
# spam\00012.381e4f512915109ba1e0853a7a8407b2  <table width="600" border="20" align="center" ...
# spam\00013.d3f0b591a65f116ea5d9d4ad919f83aa  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# spam\00014.7d38c46424f24fc8012ac15a95a2ac14  <HTML><HEAD><TITLE>FREE Motorola Cell Phone wi...
# spam\00015.048434ab64c86cf890eda1326a5643f5  <HTML><HEAD><TITLE>Lowest Rate Services</TITLE...
# spam\00016.67fb281761ca1051a22ec3f21917e7c0  \n\n\n\nWant to watch Sporting Events?--Movies...
# spam\00017.1a938ecddd047b93cbd7ed92c241e6d1  Help wanted.  We are a 14 year old fortune 500...
# spam\00018.5b2765c42b7648d41c93b9b27140b23a  DEAR FRIEND,I AM MRS.  SESE-SEKO WIDOW OF LATE...
# spam\00019.bbc97ad616ffd06e93ce0f821ca8c381  Lowest rates available for term life insurance...
# spam\00020.29725cf331fc21e18a1809e7d8b27332  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# spam\00021.effe1449462a9d7ad7af0f1c94b1a237  CENTRAL BANK OF NIGERIA\n\nFOREIGN REMITTANCE ...
# spam\00022.8203cdf03888f656dc0381701148f73d  --===_SecAtt_000_1fheucnqggtggp\n\nContent-Typ...
# spam\00023.b6d27c684f5fc803cfa1060adb2d0805  ------=_NextPart_000_00B2_83B03D1E.C6530E24\n\...
# spam\00024.6b5437b14d403176c3f046c871b5b52f  This is a multi-part message in MIME format.\n...
# spam\00025.619ab8051359048795e3cd09e82ad1a0  <HTML><HEAD>\n\n<META http-equiv=3DContent-Typ...
# spam\00026.da18dbed27ae933172f7a70f860c6ad0  DEAR FRIEND,I AM MRS.  SESE-SEKO WIDOW OF LATE...
# spam\00027.d1d0f97e096fe08fc80a4939355759e7  1) Fight The Risk of Cancer!\n\nhttp://www.adc...
# spam\00028.ace98eff213f4e6314b5571aece625e1  <HTML><HEAD><TITLE>MILFhunter</TITLE>\n\n<META...
# spam\00029.de865ad8d5ad0df985ae2f72388befba  <html>\n\n<head>\n\n</head>\n\n<body>\n\n\n\n<...
# spam\00030.0c9cdd9d4025bd55dac02719ec8d29dc  <html>\n\n\n\n<head>\n\n<meta http-equiv=3D"Co...
# ...                                                                                        ...
# ham\02471.18281d43dc0775e915267c2ea5170f1f   This is possible, however using SA as a block ...
# ham\02472.5c879dd55c3d4171e1787e8529bbd7e1   \n\n--- Martin Adamson <martin@srv0.ems.ed.ac....
# ham\02473.207afa13ad7d745dfd1344f84531ac16   ----- Original Message -----\n\nFrom: "Tim Cha...
# ham\02474.c76ffef81a2529389e6c3bbb172184d7   \n\n> Mr Tim Chapman, freelance gentleman of l...
# ham\02475.9277ee243e3f51fa53ed6be55798d360   Smith, Graham - Computing Technician wrote:\n\...
# ham\02476.de1d459426662492dd1235046b504c3d   Geege wrote a strange story:\n\n>I know a guy ...
# ham\02477.07b2069e9827cfd6f97d07eea2913d57   \n\n[Paul Moore]\n\n>    but let's walk before...
# ham\02478.40723f38488bddaf5a24ef2a91679c75   On Mon, Nov 25, 2002 at 06:54:49PM +0000, Phil...
# ham\02479.14365bcad3a60fcf24c5c1813f6291fb   \n\nI don't know how one can expect better and...
# ham\02480.72714df60c9be29d6f7985c777cbfc13   No, you need to learn how declarations work in...
# ham\02481.176b368fe4b90682f33647d65a8b97a3   \n\n    Richie> As I understand it, post-1.8x ...
# ham\02482.35c166ec6a85e108ad693ea43329762f   \n\n    Paul> I suspect the best answer is to ...
# ham\02483.ab1bee02c10ddecc0e86c39eaebc2996   The Times\n\n\n\n \n\n December 04, 2002 \n\n ...
# ham\02484.32a0bca2600788be144b93cae341efbf   I have to say I was surprised about Jacko dang...
# ham\02485.ba9aebbdbec0d9fecec595eeebe5db87   Now then I recently read a novel about exactly...
# ham\02486.bdf90e871b673fd14f47f3fe36622742   What the hell is it with these mini remote con...
# ham\02487.c2e725d509201dc30debb7bd94d07f5e   here, for your enjoyment, is a little somethin...
# ham\02488.68fed64ff8169f1505b74080bb7b6158   Sean O'Donnell wrote:\n\n> Doesnt answer your ...
# ham\02489.85c20a6f9d75714d9f44398baeddd416   Joe McNally writes:\n\n\n\n> What the hell is ...
# ham\02490.7be0f683db6994ddd8445cdcc2eb5042   http://news.bbc.co.uk/1/hi/world/europe/254182...
# ham\02491.c26245be2a5096fa86647d594561c511   Hi all.\n\nDoes anyone know how to set up dual...
# ham\02492.6aede44f654a1bbc60c95c7dd770e624   Carlos Luna wrote:\n\n\n\n>Hi all.\n\n>Does an...
# ham\02493.f9f2870094430b7db8b0c1052b302cf1   Hi all\n\n\n\n\n\nI have a prob when trying to...
# ham\02494.a14f2d3a9bef3f59aa419b03aee8f871   Tim Chapman writes:\n\n\n\n> http://news.bbc.c...
# ham\02495.5064946e77b3046873da91fc47656465   > I had the same problem when installing Win o...
# ham\02496.aae0c81581895acfe65323f344340856   Man killed 'trying to surf' on Tube train \n\n...
# ham\02497.60497db0a06c2132ec2374b2898084d3   Hi Gianni,\n\n\n\nA very good resource for thi...
# ham\02498.09835f512f156da210efb99fcc523e21   Gianni Ponzi wrote:\n\n> I have a prob when tr...
# ham\02499.b4af165650f138b10f9941f6cc5bce3c   Neale Pickett <neale@woozle.org> writes:\n\n\n...
# ham\02500.05b3496ce7bca306bed0805425ec8621   \n\nHi,\n\n\n\nI think you need to give us a l...
#
# [3000 rows x 2 columns]

# %% [markdown]
# Now we will use a CountVectorizer to split up each message into its list of words, and throw that into a MultinomialNB classifier. Call fit() and we've got a trained spam filter ready to go.

# %%
vectorizer = CountVectorizer()
counts = vectorizer.fit_transform(data['message'].values)

classifier = MultinomialNB()
targets = data['class'].values
classifier.fit(counts, targets)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %% [markdown]
# Let's try out couple examples.

# %%
examples = ['free viagra', "Hi Bob, how about a game of golf tomorrow?"]
example_counts = vectorizer.transform(examples)
predictions = classifier.predict(example_counts)
predictions
# Out:
# array(['spam', 'ham'],
#       dtype='<U4')

# %% [markdown]
# The first message 'free viagra' was correctly classified as **spam** and the second message, seems to be an actual question, was classified as **non spam**.
