# %% [markdown]
# # Word2Vec
#
# The point of this lesson is to introduce how to represent categorical variables.

# %%
import tensorflow as tf
import numpy as np
from sklearn.manifold import TSNE

import zipfile
import collections

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data('data/text8.zip')
print('Data size %d' % len(words))
print(words[:10])
# Out:
# Data size 17005207
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
# %%time
skip_window = 1
instances = len(data) - 2*skip_window
context = np.zeros((instances,skip_window*2+1),dtype=np.int32)
labels = np.zeros((instances,1),dtype=np.int32)

k = 0
for i in range(skip_window, len(data)-skip_window):
    context[k] = data[i-skip_window:i+skip_window+1] # Get surrounding words
    labels[k] = data[i] # Get target variable
    k += 1
    
context = np.delete(context,skip_window,1) # delete the middle word
    
############################
# Chunk the data to be passed into the tensorflow Model
###########################
data_idx = 0
def generate_batch(batch_size):
    global data_idx

    if data_idx+batch_size<instances:
        batch_labels = labels[data_idx:data_idx+batch_size]
        batch_word_data = context[data_idx:data_idx+batch_size]
        data_idx += batch_size
    else:
        overlay = batch_size - (instances-data_idx)
        batch_labels = np.vstack([labels[data_idx:instances],labels[:overlay]])
        batch_word_data = np.vstack([context[data_idx:instances],context[:overlay]])
        data_idx = overlay
    batch_word_data = np.reshape(batch_word_data,(-1,1))

    return batch_labels, batch_word_data
# Out:
# CPU times: user 38.7 s, sys: 812 ms, total: 39.5 s
# Wall time: 41.6 s

# %%
print( [reverse_dictionary[bi] for bi in data[:40]])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to']

# %%
labels_, batch = generate_batch(20)
print('\n    batch:', [reverse_dictionary[bi] for bi in batch.ravel()])
print('\n    labels:', [reverse_dictionary[li] for li in labels_.ravel()])
# Out:
#     batch: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of', 'term', 'abuse', 'of', 'first', 'abuse', 'used', 'first', 'against', 'used', 'early', 'against', 'working', 'early', 'class', 'working', 'radicals', 'class', 'including', 'radicals', 'the', 'including', 'diggers', 'the', 'of', 'diggers', 'the', 'of', 'english', 'the', 'revolution', 'english', 'and']
#
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution']

# %% [markdown]
# Shuffle the data:

# %%
data_idx = 0
shuffle_idx = np.random.permutation(instances) # create a random permutation to shuffle
labels = labels[shuffle_idx]
context = context[shuffle_idx]

# %% [markdown]
# ## Tensorflow model: (Continuous Bag of Words - CBoW)

# %%
context_window = 2*skip_window
batch_size = 128*context_window
embedding_size = 128 # Dimension of the embedding vector.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_examples = np.random.choice(100,16,replace=False) # Choose 16 words from top 100
num_sampled = 64 # Number of negative examples to sample.

sum_ids = np.repeat(np.arange(batch_size/context_window, dtype=np.int32),context_window)

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size/context_window, 1])
    segment_ids = tf.constant(sum_ids, dtype=tf.int32)
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                             stddev=1.0 / np.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]),trainable=False)

    # Model.
    # Look up embeddings for inputs.
    embed = tf.segment_mean(tf.nn.embedding_lookup(embeddings, train_dataset),segment_ids)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, inputs=embed,
                                   labels = train_labels, num_sampled = num_sampled, num_classes = vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
#     tf.initialize_all_variables().run()
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_labels, batch_data = generate_batch(int(batch_size/context_window))
        feed_dict = {train_dataset : batch_data.ravel(), train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        ############
        # Calculate average loss (every 2000 steps)
        ################
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        ####################
        
        ##################
        # Check with the validation set (every 10000 steps)
        ##################
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(len(valid_examples)):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word) # append the k-the nearest word
                print(log)

    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.554883
# Nearest to people: transmitting, hsv, existence, imperatoribus, brahmagupta, reserving, ludo, hallmark,
# Nearest to a: heighten, condoleezza, explode, unverified, lieberman, hammerstein, fort, garner,
# Nearest to four: tambo, aiding, fungal, sparks, whereby, sufferers, gylfaginning, mcvie,
# Nearest to an: feather, shuffling, dabbled, swf, weighed, static, searle, farming,
# Nearest to may: iers, undergrowth, stifling, irda, charing, mustaine, kerk, predecessors,
# Nearest to the: predictability, constituent, pelias, engaged, boziz, mime, erickson, carroll,
# Nearest to two: posner, springs, wishing, doubled, tangents, anarchistic, state, squarepants,
# Nearest to when: maluku, landholdings, bahrain, proven, morpheus, samaria, sligo, projekt,
# Nearest to after: subtitled, merge, debussy, na, korzybski, reinhard, appletalk, factional,
# Nearest to as: nawaf, screech, pulling, arrowhead, une, lessened, behavioral, teach,
# Nearest to they: darkest, regi, warwickshire, grattan, amerindians, ubangi, bukovina, tehran,
# Nearest to his: fueling, variations, entomologist, kerry, teleological, johansen, lifeless, exposition,
# Nearest to no: influenza, boleyn, letters, brilliance, spraying, bresson, contrast, manifestations,
# Nearest to zero: curling, ids, uptime, eval, postman, topple, aliphatic, azrael,
# Nearest to or: contemplative, mulder, tottenham, agni, urged, pat, giscard, casein,
# Nearest to more: it, severly, earthworms, robot, alkane, hh, cyclopentadienyl, etna,
# Average loss at step 2000: 4.943715
# Average loss at step 4000: 4.041589
# Average loss at step 6000: 3.758504
# Average loss at step 8000: 3.607269
# Average loss at step 10000: 3.494312
# Nearest to people: nursed, growing, you, jawaharlal, transmitting, issuing, especially, gutierrez,
# Nearest to a: the, bystanders, any, condoleezza, tonne, garner, aino, respect,
# Nearest to four: seven, two, five, eight, six, nine, three, zero,
# Nearest to an: dabbled, farming, swf, its, shuffling, bribery, sdtv, doonesbury,
# Nearest to may: can, will, would, illusory, could, revue, pattern, astro,
# Nearest to the: its, his, their, any, a, this, engaged, each,
# Nearest to two: four, three, one, five, seven, six, eight, nine,
# Nearest to when: into, surveyors, lost, lughnasadh, if, although, economy, wrote,
# Nearest to after: for, before, stub, under, ferrara, spend, in, during,
# Nearest to as: where, pulling, by, prove, in, gotham, rukh, kaj,
# Nearest to they: you, there, we, who, he, it, resolver, recently,
# Nearest to his: their, her, its, the, abi, s, sacco, yorker,
# Nearest to no: influenza, chemotherapeutic, games, spraying, polskiej, baluchistan, inverses, lil,
# Nearest to zero: five, seven, six, nine, eight, four, three, two,
# Nearest to or: and, com, than, pat, regrettable, overturn, notable, xu,
# Nearest to more: you, less, fleeting, even, comoros, very, fanatic, etna,
# Average loss at step 12000: 3.416225
# Average loss at step 14000: 3.352896
# Average loss at step 16000: 3.294057
# Average loss at step 18000: 3.255733
# Average loss at step 20000: 3.211604
# Nearest to people: those, gutierrez, growing, man, things, emir, affirms, you,
# Nearest to a: the, another, any, bystanders, aino, tonne, garner, flesh,
# Nearest to four: five, seven, six, eight, three, two, nine, zero,
# Nearest to an: dabbled, sdtv, swf, bribery, farming, shuffling, minarets, revolutionize,
# Nearest to may: can, will, would, could, must, cannot, illusory, might,
# Nearest to the: its, any, their, each, a, this, his, engaged,
# Nearest to two: three, four, seven, five, six, eight, one, nine,
# Nearest to when: if, although, before, surveyors, after, into, undertook, since,
# Nearest to after: before, during, stub, afterwards, for, under, in, when,
# Nearest to as: pulling, lothar, permeability, nawaf, prove, gotham, where, became,
# Nearest to they: we, you, he, there, it, she, who, erase,
# Nearest to his: her, their, its, my, abi, your, the, sacco,
# Nearest to no: influenza, letters, inverses, lil, polskiej, any, porpoise, baluchistan,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to or: and, than, regrettable, com, pat, br, cleaned, kitzmiller,
# Nearest to more: less, very, most, longer, fleeting, comoros, smaller, even,
# Average loss at step 22000: 3.186021
# Average loss at step 24000: 3.156962
# Average loss at step 26000: 3.133191
# Average loss at step 28000: 3.103540
# Average loss at step 30000: 3.083708
# Nearest to people: man, gutierrez, those, things, emir, children, mathematicians, etymologically,
# Nearest to a: another, the, garner, bystanders, any, aino, taken, tonne,
# Nearest to four: five, seven, six, three, eight, two, nine, zero,
# Nearest to an: sdtv, dabbled, swf, shuffling, bribery, minarets, gestures, cubical,
# Nearest to may: can, will, would, could, must, cannot, might, should,
# Nearest to the: its, their, any, his, each, engaged, a, atone,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to when: if, before, although, after, despite, during, where, as,
# Nearest to after: before, during, afterwards, when, stub, began, under, in,
# Nearest to as: pulling, lothar, when, gotham, certification, nestorian, gluons, where,
# Nearest to they: we, you, he, there, she, it, who, orbiter,
# Nearest to his: her, their, its, my, your, abi, the, sacco,
# Nearest to no: inverses, influenza, any, polskiej, lil, letters, a, arranges,
# Nearest to zero: five, seven, six, four, eight, nine, three, two,
# Nearest to or: and, than, pat, kitzmiller, regrettable, arithmetic, censorship, icann,
# Nearest to more: less, very, smaller, most, longer, sensation, herself, rather,
# Average loss at step 32000: 3.064044
# Average loss at step 34000: 3.042203
# Average loss at step 36000: 3.027012
# Average loss at step 38000: 3.004646
# Average loss at step 40000: 2.996604
# Nearest to people: man, gutierrez, emir, things, children, men, those, etymologically,
# Nearest to a: another, any, tonne, bystanders, garner, relatively, the, respect,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to an: sdtv, bribery, dabbled, swf, shuffling, revolutionize, minarets, cubical,
# Nearest to may: can, will, would, could, must, cannot, might, should,
# Nearest to the: its, their, your, any, each, his, patented, our,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to when: if, before, although, after, as, during, parallelism, where,
# Nearest to after: before, during, afterwards, when, under, stub, began, from,
# Nearest to as: pulling, when, gluons, gotham, lothar, certification, virility, nestorian,
# Nearest to they: we, you, there, he, she, it, often, who,
# Nearest to his: her, their, its, my, your, the, abi, sacco,
# Nearest to no: any, inverses, influenza, polskiej, procedures, matt, a, letters,
# Nearest to zero: five, eight, seven, four, six, nine, three, two,
# Nearest to or: and, than, icann, pat, brenner, purple, kitzmiller, deference,
# Nearest to more: less, very, most, smaller, longer, herself, integrates, rather,
# Average loss at step 42000: 2.980107
# Average loss at step 44000: 2.966837
# Average loss at step 46000: 2.954439
# Average loss at step 48000: 2.946247
# Average loss at step 50000: 2.930570
# Nearest to people: man, things, emir, men, etymologically, gutierrez, children, women,
# Nearest to a: another, garner, relatively, tonne, the, any, vibrato, bystanders,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to an: sdtv, cubical, dabbled, bribery, swf, gestures, sinn, hdz,
# Nearest to may: can, will, would, could, must, might, cannot, should,
# Nearest to the: its, their, any, your, our, his, each, atone,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to when: if, before, although, after, though, during, as, where,
# Nearest to after: before, during, afterwards, when, began, despite, stub, while,
# Nearest to as: pulling, when, lothar, nawaf, nestorian, digested, gotham, certification,
# Nearest to they: we, he, you, there, she, it, eventually, these,
# Nearest to his: her, their, my, its, your, stream, yorker, the,
# Nearest to no: any, inverses, influenza, procedures, matt, crumble, polskiej, letters,
# Nearest to zero: five, seven, six, eight, four, nine, three, two,
# Nearest to or: and, than, dur, kitzmiller, pat, masked, icann, purple,
# Nearest to more: less, very, most, longer, smaller, particularly, increasingly, better,
# Average loss at step 52000: 2.911720
# Average loss at step 54000: 2.902270
# Average loss at step 56000: 2.894898
# Average loss at step 58000: 2.882166
# Average loss at step 60000: 2.878007
# Nearest to people: man, men, women, things, children, emir, etymologically, mathematicians,
# Nearest to a: another, tonne, relatively, any, garner, bystanders, enough, every,
# Nearest to four: six, five, seven, three, eight, two, nine, zero,
# Nearest to an: sdtv, dabbled, bribery, cubical, minarets, shuffling, gestures, swf,
# Nearest to may: can, will, would, could, must, might, should, cannot,
# Nearest to the: its, their, any, your, our, his, each, speeds,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to when: if, before, although, though, while, where, after, during,
# Nearest to after: before, during, afterwards, despite, when, began, without, while,
# Nearest to as: pulling, when, gluons, digested, nestorian, lothar, religiosity, certification,
# Nearest to they: we, he, you, she, there, it, eventually, these,
# Nearest to his: her, their, my, your, its, abi, stream, the,
# Nearest to no: any, inverses, influenza, procedures, little, matt, polskiej, nothing,
# Nearest to zero: five, six, four, seven, eight, nine, three, two,
# Nearest to or: and, than, kitzmiller, purple, masked, gila, xaver, though,
# Nearest to more: less, most, very, longer, smaller, particularly, better, increasingly,
# Average loss at step 62000: 2.872135
# Average loss at step 64000: 2.865061
# Average loss at step 66000: 2.851598
# Average loss at step 68000: 2.849238
# Average loss at step 70000: 2.844397
# Nearest to people: women, man, men, children, things, etymologically, mathematicians, anyone,
# Nearest to a: another, relatively, garner, tonne, any, auditory, vibrato, vaccines,
# Nearest to four: five, six, seven, eight, three, nine, two, zero,
# Nearest to an: sdtv, dabbled, swf, bribery, gestures, cubical, shuffling, revolutionize,
# Nearest to may: can, will, must, could, would, might, should, cannot,
# Nearest to the: its, their, his, our, your, atone, any, zeus,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to when: if, before, because, while, after, although, though, where,
# Nearest to after: before, during, afterwards, when, without, despite, while, began,
# Nearest to as: pulling, gluons, religiosity, nestorian, when, gretchen, esas, gotham,
# Nearest to they: we, he, you, there, she, it, eventually, i,
# Nearest to his: her, their, my, its, your, the, abi, our,
# Nearest to no: any, inverses, nothing, influenza, little, procedures, matt, polskiej,
# Nearest to zero: seven, five, six, eight, four, nine, three, two,
# Nearest to or: and, than, kitzmiller, newtons, trusting, purple, heterogeneous, despotism,
# Nearest to more: less, most, very, longer, smaller, better, particularly, increasingly,
# Average loss at step 72000: 2.827556
# Average loss at step 74000: 2.822433
# Average loss at step 76000: 2.816873
# Average loss at step 78000: 2.810711
# Average loss at step 80000: 2.805965
# Nearest to people: women, men, man, things, children, etymologically, mathematicians, anyone,
# Nearest to a: another, relatively, tonne, garner, the, bystanders, any, vibrato,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to an: sdtv, dabbled, cubical, bribery, swf, freebsd, gestures, minarets,
# Nearest to may: can, will, must, could, would, should, might, cannot,
# Nearest to the: their, its, our, his, any, atone, speeds, your,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to when: if, before, while, after, although, where, because, parallelism,
# Nearest to after: before, during, afterwards, despite, when, without, while, from,
# Nearest to as: pulling, gluons, when, religiosity, nestorian, lothar, infinitives, nawaf,
# Nearest to they: we, he, there, you, she, it, eventually, these,
# Nearest to his: her, their, my, its, your, our, abi, the,
# Nearest to no: any, inverses, little, influenza, nothing, matt, polskiej, crumble,
# Nearest to zero: five, six, seven, eight, four, nine, three, million,
# Nearest to or: and, than, though, kitzmiller, purple, trusting, dur, socialized,
# Nearest to more: less, most, very, longer, smaller, particularly, quite, increasingly,
# Average loss at step 82000: 2.795960
# Average loss at step 84000: 2.788086
# Average loss at step 86000: 2.788689
# Average loss at step 88000: 2.788182
# Average loss at step 90000: 2.765954
# Nearest to people: women, men, man, things, children, mathematicians, anyone, etymologically,
# Nearest to a: another, tonne, relatively, any, garner, the, every, bystanders,
# Nearest to four: five, six, three, seven, eight, two, nine, zero,
# Nearest to an: sdtv, dabbled, bribery, shuffling, cubical, gestures, swf, minarets,
# Nearest to may: can, will, must, could, would, might, should, cannot,
# Nearest to the: their, its, our, his, any, this, atone, your,
# Nearest to two: three, four, five, six, seven, eight, one, nine,
# Nearest to when: if, before, while, although, after, where, because, though,
# Nearest to after: before, during, afterwards, despite, when, without, while, thereafter,
# Nearest to as: pulling, when, presents, nestorian, gluons, infinitives, religiosity, gotham,
# Nearest to they: we, he, there, you, she, it, these, eventually,
# Nearest to his: her, their, my, your, its, our, the, meritorious,
# Nearest to no: any, little, inverses, nothing, influenza, matt, crumble, procedures,
# Nearest to zero: five, eight, four, seven, six, nine, three, million,
# Nearest to or: and, than, purple, icann, gila, kitzmiller, trusting, ga,
# Nearest to more: less, most, very, smaller, longer, quite, particularly, increasingly,
# Average loss at step 92000: 2.767735
# Average loss at step 94000: 2.759326
# Average loss at step 96000: 2.751457
# Average loss at step 98000: 2.751288
# Average loss at step 100000: 2.745317
# Nearest to people: women, men, man, things, children, jews, gutierrez, mathematicians,
# Nearest to a: another, relatively, tonne, bystanders, enough, any, the, every,
# Nearest to four: five, six, seven, three, eight, nine, two, zero,
# Nearest to an: sdtv, bribery, cubical, gestures, hdz, swf, shuffling, dabbled,
# Nearest to may: can, will, must, could, would, might, should, cannot,
# Nearest to the: its, their, atone, his, our, any, your, mestre,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to when: if, although, while, before, because, after, though, where,
# Nearest to after: before, during, afterwards, despite, without, when, while, thereafter,
# Nearest to as: pulling, when, othniel, presents, gluons, nestorian, wonderful, lothar,
# Nearest to they: we, he, there, you, she, it, these, i,
# Nearest to his: her, their, my, your, its, our, whose, the,
# Nearest to no: any, little, nothing, inverses, influenza, matt, crumble, procedures,
# Nearest to zero: five, eight, seven, six, four, nine, three, two,
# Nearest to or: and, than, icann, purple, masked, gila, though, newtons,
# Nearest to more: less, most, very, smaller, longer, quite, better, particularly,

# %%
final_embeddings.shape
# Out:
# (50000, 128)

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

def plot(embeddings, labels):
    plt.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        plt.scatter(x, y)
        plt.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                       ha='right', va='bottom')
    plt.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
